# %%
import pandas as pd
import random
import seaborn as sns
from math import sqrt
df = pd.read_csv('TacoBellCustomers.csv')

# %%
df
# Out:
#        Unnamed: 0      ID  Gender Ever_Married  Age Graduated  Profession  \
# 0               0  458989  Female          Yes   36       Yes    Engineer
# 1               1  458994    Male          Yes   37       Yes  Healthcare
# 2               2  458996  Female          Yes   69        No         NaN
# 3               3  459000    Male          Yes   59        No   Executive
# 4               4  459001  Female           No   19        No   Marketing
# ...           ...     ...     ...          ...  ...       ...         ...
# 10690        8063  464018    Male           No   22        No         NaN
# 10691        8064  464685    Male           No   35        No   Executive
# 10692        8065  465406  Female           No   33       Yes  Healthcare
# 10693        8066  467299  Female           No   27       Yes  Healthcare
# 10694        8067  461879    Male          Yes   37       Yes   Executive
#
#        Work_Experience Spending_Score  Family_Size State_Purchased
# ...

# %%
df.drop(['Work_Experience','Ever_Married','Graduated','ID','Unnamed: 0','Profession'], axis =1, inplace =True)

df.dropna(axis = 0, inplace = True)
df.reset_index(drop = True, inplace = True)

# %%
df
# df['State_Purchased'].value_counts()
# Out:
#        Gender  Age Spending_Score  Family_Size State_Purchased
# 0      Female   36            Low          1.0         Indiana
# 1        Male   37        Average          4.0          Kansas
# 2      Female   69            Low          1.0         Indiana
# 3        Male   59           High          2.0  South Carolina
# 4      Female   19            Low          4.0      Washington
# ...       ...  ...            ...          ...             ...
# 10242    Male   22            Low          7.0  North Carolina
# 10243    Male   35            Low          4.0        Arkansas
# 10244  Female   33            Low          1.0        Michigan
# 10245  Female   27            Low          4.0        Missouri
# 10246    Male   37        Average          3.0         Florida
#
# [10247 rows x 5 columns]

# %%
topStates = []

for i in range(len(df.index)):
    states = df.iat[i,4]
    spending = df.iat[i,2]
    if spending == 'High':
        topStates.append(states)
        
        
        
topStates = sorted(topStates)
topStates

#'Cali','Texas','Floria','Ohio','Michigan'
topStates.count(''),

def most_common(lst):
    return max(set(lst), key=lst.count)


most_common(topStates)
# Out:
# 'California'

# %%
for i in' ':
    df["State_Purchased"] = df['State_Purchased'].str.replace(i, '', regex=False)
    df['State_Purchased'] = df['State_Purchased'].str.replace("\d", '', regex=True)



def getTopSpamWords(df, numWords):
    spamWords = {}
    for idx in range(len(df.index)):
      #  if df.iat[idx,0] == 'spam':
            message = df.iat[idx,4]
            message = message.split()
            for word in message:
                    if word not in spamWords:                      
                        spamWords[word] = 1
                    else:
                        spamWords[word] = spamWords[word] + 1
                        
                        
                        
    spamWords = sorted(spamWords.items(), key = lambda x:x[1], reverse = True)
    topSpam = spamWords[:numWords]
                        
    return spamWords

result = getTopSpamWords(df,5)

print(result)
# Out:
# [('California', 1162), ('Texas', 880), ('Florida', 623), ('Ohio', 515), ('Michigan', 408), ('Illinois', 385), ('Tennessee', 360), ('Indiana', 349), ('NorthCarolina', 340), ('Georgia', 336), ('NewYork', 331), ('Missouri', 327), ('Pennsylvania', 289), ('Virgina', 265), ('Arizona', 238), ('Colorado', 222), ('Kentucky', 221), ('Wisconsin', 196), ('Alabama', 189), ('Washington', 181), ('Louisana', 168), ('Oregon', 167), ('SouthCarolina', 160), ('NewJersey', 158), ('Oklahoma', 156), ('Kansas', 148), ('Arkansas', 130), ('Maryland', 128), ('Minnesota', 126), ('Massachusetts', 121), ('Mississippi', 107), ('Utah', 93), ('WestVirgina', 93), ('Nevada', 91), ('NewMexico', 83), ('Iowa', 76), ('Connecticut', 66), ('Nebraska', 49), ('Hawaii', 46), ('Idaho', 45), ('Maine', 38), ('Montana', 35), ('NewHampshire', 25), ('Delaware', 25), ('SouthDakota', 21), ('RhodeIsland', 21), ('Wyoming', 17), ('Vermont', 14), ('NorthDakota', 12), ('Alaska', 11)]

# %%
#df.drop(df[(df.State_Purchased != ['California']) & (df.State_Purchased != ['Texas']) & (df.State_Purchased != ['Floria']) & (df.State_Purchased != ['Ohio']) & (df.State_Purchased != ['Michigan'
#])].index, inplace=True)

# %%
df = df.drop(df[(df.State_Purchased != 'California') & (df.State_Purchased != 'Texas') & (df.State_Purchased != 'Florida') & (df.State_Purchased != 'Ohio') & (df.State_Purchased != 'Michigan')].index)
 
df.reset_index()
# Out:
#       index  Gender  Age Spending_Score  Family_Size State_Purchased
# 0         7  Female   47        Average          3.0            Ohio
# 1        13    Male   27            Low          3.0           Texas
# 2        16  Female   20        Average          3.0            Ohio
# 3        17    Male   45        Average          2.0           Texas
# 4        18    Male   55            Low          1.0         Florida
# ...     ...     ...  ...            ...          ...             ...
# 3583  10238    Male   39            Low          2.0         Florida
# 3584  10239  Female   48        Average          6.0      California
# 3585  10240    Male   65        Average          2.0         Florida
# 3586  10244  Female   33            Low          1.0        Michigan
# 3587  10246    Male   37        Average          3.0         Florida
#
# [3588 rows x 6 columns]

# %%
#Switching string with ints

sex = {'Male': 0, 'Female': 1}

df.Gender = [sex[item] for item in df.Gender]

spending = {'Low': 2, 'Average': 4, 'High': 6}

df.Spending_Score = [spending[item] for item in df.Spending_Score]

state = {'Califorina': 7, 'Texas': 8, 'Florida': 9, 'Ohio': 10, 'Michigan': 11}

df.State_Purchased = [sex[item] for item in df.State_Purchased]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16760\2445120677.py in <module>
#       3 sex = {'Male': 0, 'Female': 1}
#       4
# ----> 5 df.Gender = [sex[item] for item in df.Gender]
#       6
#       7 spending = {'Low': 2, 'Average': 4, 'High': 6}
#
# ~\AppData\Local\Temp\ipykernel_16760\2445120677.py in <listcomp>(.0)
#       3 sex = {'Male': 0, 'Female': 1}
#       4
# ----> 5 df.Gender = [sex[item] for item in df.Gender]
#       6
#       7 spending = {'Low': 2, 'Average': 4, 'High': 6}
#
# KeyError: 1

# %%
#Counting
#df['name'].value_counts()
state = {'California': 7, 'Texas': 8, 'Florida': 9, 'Ohio': 10, 'Michigan': 11}

df.State_Purchased = [state[item] for item in df.State_Purchased]

# %%
df_min_max_scaled = df.copy()
  

for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  

print(df_min_max_scaled)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16760\598445929.py in <module>
#       3
#       4 for column in df_min_max_scaled.columns:
# ----> 5     df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())
#       6
#       7
#
# ...

# %%
df_min_max_scaled
# Out:
#        Gender       Age  Spending_Score  Family_Size State_Purchased
# 7         1.0  0.408451             0.5        0.250            Ohio
# 13        0.0  0.126761             0.0        0.250           Texas
# 16        1.0  0.028169             0.5        0.250            Ohio
# 17        0.0  0.380282             0.5        0.125           Texas
# 18        0.0  0.521127             0.0        0.000         Florida
# ...       ...       ...             ...          ...             ...
# 10238     0.0  0.295775             0.0        0.125         Florida
# 10239     1.0  0.422535             0.5        0.625      California
# 10240     0.0  0.661972             0.5        0.125         Florida
# 10244     1.0  0.211268             0.0        0.000        Michigan
# 10246     0.0  0.267606             0.5        0.250         Florida
#
# [3588 rows x 5 columns]

# %%
def testTrainSplit(data):
  length = len(df_min_max_scaled.index)
  splitLimit = int(length * 0.7)
  train = data[0: splitLimit]
  test = data[splitLimit + 1: length]
  return train, test

# %%
train, test = testTrainSplit(df_min_max_scaled)

# %%
train
# Out:
#       Gender       Age  Spending_Score  Family_Size State_Purchased
# 7        1.0  0.408451             0.5        0.250            Ohio
# 13       0.0  0.126761             0.0        0.250           Texas
# 16       1.0  0.028169             0.5        0.250            Ohio
# 17       0.0  0.380282             0.5        0.125           Texas
# 18       0.0  0.521127             0.0        0.000         Florida
# ...      ...       ...             ...          ...             ...
# 7170     0.0  0.211268             0.0        0.375      California
# 7172     0.0  0.859155             0.0        0.000        Michigan
# 7174     0.0  0.352113             0.5        0.125           Texas
# 7176     1.0  0.563380             0.0        0.125           Texas
# 7177     0.0  0.464789             0.5        0.500           Texas
#
# [2511 rows x 5 columns]

# %%
test
# Out:
#        Gender       Age  Spending_Score  Family_Size State_Purchased
# 7187      0.0  0.338028             0.0        0.000      California
# 7188      1.0  0.028169             0.0        0.250         Florida
# 7195      1.0  0.183099             0.0        0.125         Florida
# 7198      0.0  0.549296             0.5        0.250      California
# 7201      0.0  0.309859             0.0        0.125            Ohio
# ...       ...       ...             ...          ...             ...
# 10238     0.0  0.295775             0.0        0.125         Florida
# 10239     1.0  0.422535             0.5        0.625      California
# 10240     0.0  0.661972             0.5        0.125         Florida
# 10244     1.0  0.211268             0.0        0.000        Michigan
# 10246     0.0  0.267606             0.5        0.250         Florida
#
# [1076 rows x 5 columns]

# %%
K = 3

#chooses 4 random values from the training dataframe
Centroids = (train.sample(n=K))

# %%
Centroids

# %%
diff = 1
j=0

while(diff!=0):
    XD=train
    i=1
    for index1, row_c in Centroids.iterrows():
        ED=[]
        for index2, row_d in XD.iterrows():
            d1 = (row_c["Gender"]-row_d["Gender"])**2
            d2 = (row_c["Age"]-row_d["Age"])**2
            d3 = (row_c["Spending_Score"]-row_d["Spending_Score"])**2
            d4 = (row_c["Family_Size"]-row_d["Family_Size"])**2
            d = sqrt(d1+d2+d3+d4)
            ED.append(d)
        train[i] = ED
        i = i+1
    
    C = []
    for index, row in train.iterrows():
        min_dist=row[1]
        pos=1
        for i in range(K):
            if row[i+1] < min_dist:
                min_dist = row[i+1]
                pos = i+1
        C.append(pos)
    train["Cluster"]=C
    Centroids_new = train.groupby(["Cluster"]).mean()[["Age", "Gender","Spending_Score","Family_Size"]]
    if j == 0:
        diff = 1
        j = j+1
    else:
        diff = (Centroids_new['Age'] - Centroids['Age']).sum() + (Centroids_new['Gender'] - Centroids['Gender']).sum()+(Centroids_new['Spending_Score'] - Centroids['Spending_Score']).sum() + (Centroids_new['Family_Size'] - Centroids['Family_Size']).sum()
        print(diff.sum())
    Centroids = train.groupby(["Cluster"]).mean()[["Age","Gender","Spending_Score","Family_Size"]]

# %%
from sklearn.cluster import KMeans
ks=[]
for i in range(1,5):
    ks.append(i)
df = df.copy([['Spending_Score', 'State_Purchased','Family_Size','Age','Gender']])

# %%
wcss = []


for i in range(1, 5):
    clustering = KMeans(n_clusters=i, init='k-means++', random_state=42)
    clustering.fit(df)
    wcss.append(clustering.inertia_)
    
data = {"KValue":ks,"Variation":wcss}
df2 = pd.DataFrame(data)
sns.lineplot(data=df2, x = "KValue", y = "Variation");
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=15.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
axes = plt.axes(projection='3d')
print(type(axes))
axes.scatter3D(df['Spending_Score'], df['State_Purchased'], df['Age'])

axes.set_xlabel('Money')
axes.set_ylabel('State')
axes.set_zlabel('Age')

axes.view_init(45,45)
# Out:
# <class 'matplotlib.axes._subplots.Axes3DSubplot'>

# %%
import seaborn as sns

sns.barplot(data=df, x="State_Purchased", y="Spending_Score")
# Out:
# <AxesSubplot:xlabel='State_Purchased', ylabel='Spending_Score'>

# %%
sns.barplot(data=df, x="State_Purchased", y="Age")
# Out:
# <AxesSubplot:xlabel='State_Purchased', ylabel='Age'>

# %%
sns.barplot(data=df, x="Age", y = 'Family_Size'
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Family_Size'>

# %%
sns.barplot(data=df, x="Gender", y="Spending_Score")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Spending_Score'>

# %%
sns.barplot(data=df, x="State_Purchased", y="Gender")
# Out:
# <AxesSubplot:xlabel='State_Purchased', ylabel='Gender'>

# %%
sns.barplot(data=df, x="Family_Size", y="Spending_Score")
# Out:
# <AxesSubplot:xlabel='Family_Size', ylabel='Spending_Score'>
